# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings("ignore")

# %%
# why seaborn >> more attractive plots
# >> more options for statistical 

# seaborn is python data visualisation tool based on matpolotlib , it provides a high interface for drawing attractive and informative statistical graphs >

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.shape
# Out:
# (244, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
# numerical data ploting in seaborn 
# relplot has options for ploting for both categorical and neumerical data 
# relplot >> how the relation between two  variables 
# relpolt >> relationship plot 
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# how tip is varying wrt bill >> scatter plot / by default relplot makes scatter plot

sns.relplot(x = "total_bill", y = "tip", data = df) # relation bet two variable , bydefault >> scatter plot,, want to change??  >> kind = "line"
# insight >> total bill incrses then tip increases

# %%
sns.relplot(x = "total_bill", y = "tip", data = df, hue= "smoker") 
# insight >> custemer who smoked gives the highest tip

# %%
sns.relplot(x = "total_bill", y = "tip", data = df, hue = "size")
# hue also gives diffrent color sets

# %%
sns.relplot(x = "total_bill", y = "tip", data = df, style = "size") # style gives the representation of the column value

# %%
sns.relplot(x = "total_bill", y = "tip", data = df, style = "smoker", hue = "time")

# %%
# relplot for making a line plot >> genrate a data
# line plot >> to understand the trend in data , a time column/sequence genrally is there

# %%
time = np.arange(500)
value = np.random.randn(500).cumsum()
df = pd.DataFrame({'time' : time , 'value': value})
df
# Out:
#      time      value
# 0       0   2.031527
# 1       1   0.485221
# 2       2   0.551012
# 3       3   0.827411
# 4       4  -0.139872
# ..    ...        ...
# 495   495 -15.142207
# 496   496 -13.541999
# 497   497 -15.224663
# 498   498 -15.511773
# 499   499 -15.394409
#
# [500 rows x 2 columns]

# %%
sns.relplot(x = "time", y = "value" , kind = "line", data = df,sort = True )

# %%
fmri=sns.load_dataset("fmri")
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x = "timepoint", y = "signal" , kind="line", data = fmri)

# %%
sns.relplot(x = "timepoint", y = "signal" , kind="line", data = fmri, ci = "sd")

# %%
sns.relplot(x = "timepoint", y = "signal" ,estimator = None, kind="line", data = fmri)

# %%
sns.relplot(x = "timepoint", y = "signal" , kind="line", data = fmri, hue="event")

# %%
sns.relplot(x = "timepoint", y = "signal" , kind="line", data = fmri, hue="event", style = "region")

# %%
# removes the dashes from the line chart >> sadhes = False
sns.relplot(x = "timepoint", y = "signal" , kind="line", data = fmri, hue="event", style = "region", dashes = False)

# %%
sns.relplot(x = "timepoint", y = "signal" , kind="line", data = fmri, hue="event", style = "region", markers = True)

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# two sub plots based on column 
sns.relplot(x= "total_bill", y = "tip",hue = "smoker", data = tips , col = "time")

# %%
sns.relplot(x= "total_bill", y = "tip",hue = "smoker", data = tips , col = "size")

# %%
# categorical data plots
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
# for categorical column >> catplot
# plot between day and total bill , day is a categorical column
sns.catplot(x="day",y = "total_bill",data=tips)
# insights >> many people arrivs saturday and sund compared to week days

# %%
# in catplot few data points are overlaping >> to see it separately  use swarm plot 
sns.catplot(x="day",y = "total_bill",data=tips,kind = "swarm" )

# %%
# boxplot >> to see the outlier
sns.catplot( x = "day", y = "total_bill", data=tips, kind = "box")

# %%
sns.catplot( x = "day", y = "total_bill", data=tips, kind = "violin")

# %%
# boxen plot>> made from box plot itself
sns.catplot( x = "day", y = "total_bill", data=tips, kind = "boxen")

# %%
sns.barplot(x = "day", y = "total_bill", data = tips)
# how total bill(aggregated) varies with diffrent days
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.jointplot( x = tips.total_bill , y = tips.tip) #draw a plot of two variables with distribution >> by varient graphs  >> two  plots
# joint plot to understand the relationship nd to understand the distribution of two varibles

# %%
sns.jointplot( x = tips.total_bill , y = tips.tip,kind = "reg") # regretion line to represnt relationship

# %%
# the line is kde>> kernel density estimetor >> the line called as regretion line

# %%
sns.jointplot( x = tips.total_bill , y = tips.tip,kind = "hex")

# %%
sns.jointplot( x = tips.total_bill , y = tips.tip,kind = "kde") # kde >> kernel denstity estimrtor >>the plot is contour plot >> very much use is in meteriological department

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips) # make plots >>etr all neumerical columns >> scater plot

# %%
sns.pairplot(tips, hue = "smoker")

# %%
sns.pairplot(tips, hue = "smoker", palette= "coolwarm")

# %%
# boxplot using sns directly (earlier catplot)
sns.boxplot( x= "day", y = "total_bill", data = tips,palette="rainbow")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot( data = tips,palette="rainbow", orient="h")
# Out:
# <Axes: >

# %%
df1 = tips[["total_bill","tip","size"]]
df1
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
df1.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# heat map >> vslue encoded with diffrent colours
sns.heatmap(df1.corr(),cmap="coolwarm", annot=True)
# Out:
# <Axes: >

# %%
df = sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x = "sex",data = tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x = "total_bill", y= "tip", data = df)

# %%
sns.lmplot(x = "total_bill", y= "tip", data = df, height = 15)

# %%
sns.lmplot(x = "total_bill", y= "tip", data = df, height = 15, aspect=2)

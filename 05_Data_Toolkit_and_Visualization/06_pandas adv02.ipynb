# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(100)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %%
df[0:100]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %%
df[0:100:2]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 2             3         1       3
# 4             5         0       3
# 6             7         0       1
# 8             9         1       3
# 10           11         1       3
# 12           13         0       3
# 14           15         0       3
# 16           17         0       3
# 18           19         0       3
# 20           21         0       2
# 22           23         1       3
# 24           25         0       3
# 26           27         0       3
# 28           29         1       3
# 30           31         0       1
# 32           33         1       3
# 34           35         0       1
# 36           37         1       3
# 38           39         0       3
# 40           41         0       3
# 42           43         0       3
# 44           45         1       3
# 46           47         0       3
# 48           49         0       3
# 50           51         0       3
# ...

# %%
df[0:100:5]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 5             6         0       3
# 10           11         1       3
# 15           16         1       2
# 20           21         0       2
# 25           26         1       3
# 30           31         0       1
# 35           36         0       1
# 40           41         0       3
# 45           46         0       3
# 50           51         0       3
# 55           56         1       1
# 60           61         0       3
# 65           66         1       3
# 70           71         0       2
# 75           76         0       3
# 80           81         0       3
# 85           86         1       3
# 90           91         0       3
# 95           96         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 5                                    Moran, Mr. James    male   NaN      0
# ...

# %%
# access rows and columns of a datafrme >>> implicit / integer / internal indexing , explicite or name indexing
# i i i >> i loc

# %%
# iloc 
df.iloc[0:3] # same as df.[0:3]
# starts from 0 and go till 2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.loc[0:3] # loc >> location >> used for named index
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
df.iloc[0:2]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.iloc[0:2,["Name","Sex"]] # it will through an error IndexError: .iloc requires numeric indexers, got ['Name' 'Sex']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df.iloc[0:2,["Name","Sex"]] # it will through an error
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1690, in _iLocIndexer._getitem_tuple(self, tup)
#    1689 def _getitem_tuple(self, tup: tuple):
# -> 1690     tup = self._validate_tuple_indexer(tup)
#    1691     with suppress(IndexingError):
# ...

# %%
df.loc[0:2,["Name","Sex"]] # loc is used for named and indexes ,,, iloc is used for integer indexe
# Out:
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female

# %%
df.iloc[0:2,3:6]
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0

# %%
list(df["Name"][2:5])
# Out:
# ['Heikkinen, Miss. Laina',
#  'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#  'Allen, Mr. William Henry']

# %%
s = pd.Series(list(df["Name"][2:5]),index=["a","b","c"])
s
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# dtype: object

# %%
s1 = pd.Series(list(df["Name"][5:8]))
s1
# Out:
# 0                  Moran, Mr. James
# 1           McCarthy, Mr. Timothy J
# 2    Palsson, Master. Gosta Leonard
# dtype: object

# %%
# series with diffrent indexes and dataframe can not be concatenated using "+"
s+s1
# Out:
# a    NaN
# b    NaN
# c    NaN
# 0    NaN
# 1    NaN
# 2    NaN
# dtype: object

# %%
# if indexes are same then series concatinaton can happen 
s1 = pd.Series(list(df["Name"][5:8]),index=["a","b","c"])
s1
# Out:
# a                  Moran, Mr. James
# b           McCarthy, Mr. Timothy J
# c    Palsson, Master. Gosta Leonard
# dtype: object

# %%
s
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# dtype: object

# %%
s+s1
# Out:
# a               Heikkinen, Miss. LainaMoran, Mr. James
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)Mc...
# c    Allen, Mr. William HenryPalsson, Master. Gosta...
# dtype: object

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop("PassengerId",axis=1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop("PassengerId",axis=1, inplace = True) # axis = 0 >> drop from rows, and, axis = >> drp from column ,,inplace = true means modify the original data frame

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# droping from rows
df.drop(1,inplace= True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 5                                Moran, Mr. James    male   NaN      0      0
# ...

# %%
df.reset_index(drop=True)
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              3         1       3  female  26.0      0      0
# 2              4         1       1  female  35.0      1      0
# 3              5         0       3    male  35.0      0      0
# 4              6         0       3    male   NaN      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 885          887         0       2    male  27.0      0      0
# 886          888         1       1  female  19.0      0      0
# 887          889         0       3  female   NaN      1      2
# 888          890         1       1    male  26.0      0      0
# 889          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1    STON/O2. 3101282   7.9250   NaN        S
# 2              113803  53.1000  C123        S
# ...

# %%
df
# Out:
#                                               PassengerId  Survived  Pclass  \
# Name
# Braund, Mr. Owen Harris                                 1         0       3
# Heikkinen, Miss. Laina                                  3         1       3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1       1
# Allen, Mr. William Henry                                5         0       3
# Moran, Mr. James                                        6         0       3
# ...                                                   ...       ...     ...
# Montvila, Rev. Juozas                                 887         0       2
# Graham, Miss. Margaret Edith                          888         1       1
# Johnston, Miss. Catherine Helen "Carrie"              889         0       3
# Behr, Mr. Karl Howell                                 890         1       1
# Dooley, Mr. Patrick                                   891         0       3
#
# ...

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
# set new index
df.set_index('Name', inplace = True)

# %%
df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df.loc["Braund, Mr. Owen Harris"]
# Out:
# PassengerId            1
# Survived               0
# Pclass                 3
# Sex                 male
# Age                 22.0
# SibSp                  1
# Parch                  0
# Ticket         A/5 21171
# Fare                7.25
# Cabin                NaN
# Embarked               S
# Name: Braund, Mr. Owen Harris, dtype: object

# %%
df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df.reset_index()
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# ..                                                 ...          ...       ...
# 886                              Montvila, Rev. Juozas          887         0
# 887                       Graham, Miss. Margaret Edith          888         1
# 888           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 889                              Behr, Mr. Karl Howell          890         1
# 890                                Dooley, Mr. Patrick          891         0
#
# ...

# %%
d = {"key1": [1,2,3],
     "key2": [5,6,7],
     "key3": [8,9,10]
     }
d
# Out:
# {'key1': [1, 2, 3], 'key2': [5, 6, 7], 'key3': [8, 9, 10]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     5     8
# 1     2     6     9
# 2     3     7    10

# %%
d = {"key1": (1,2,3),
     "key2": (5,6,7),
     "key3": (8,9,10)
     }
d
# Out:
# {'key1': (1, 2, 3), 'key2': (5, 6, 7), 'key3': (8, 9, 10)}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     5     8
# 1     2     6     9
# 2     3     7    10

# %%
df1 = pd.read_csv("taxonomy.csv")
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.shape
# Out:
# (290, 4)

# %%
df1.describe()
# Out:
#        taxonomy_id          name  parent_id       parent_name
# count          290           290        279               279
# unique         290           183         60                50
# top         111-05  Nursing Home  106-06-07  Health Education
# freq             1             4         11                15

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   taxonomy_id  290 non-null    object
#  1   name         290 non-null    object
#  2   parent_id    279 non-null    object
#  3   parent_name  279 non-null    object
# dtypes: object(4)
# memory usage: 9.2+ KB

# %%
df1.isnull().sum() # when ever there is null value you have to remove the null value
# Out:
# taxonomy_id     0
# name            0
# parent_id      11
# parent_name    11
# dtype: int64

# %%
# null value >> delet,   

# imputation ( replace null value with some value)

# if numerical = mean,median 
# if categerical>> mode
# with some constant

# %%
df1.shape
# Out:
# (290, 4)

# %%
df1.dropna() # remove null valeus from  rows
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1.dropna(axis=1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df1[["name"]].dropna(axis=1) # for one column
# Out:
#                              name
# 0                       Emergency
# 1               Disaster Response
# 2                  Emergency Cash
# 3               Help Pay for Food
# 4         Help Pay for Healthcare
# ..                            ...
# 285              Workplace Rights
# 286                     Mediation
# 287                        Notary
# 288                Representation
# 289  Translation & Interpretation
#
# [290 rows x 1 columns]

# %%
# imputation of missing value >>> replacing missing values with some values 
# numeric data >> mean and median >> outliar (abnormal),value treatment is done, then use mean 
# categerical data >> mode
# impute missing data with some constant i.e = 0

# %%
df1.fillna("somevalues")
# Out:
#     taxonomy_id                          name   parent_id  \
# 0           101                     Emergency  somevalues
# 1        101-01             Disaster Response         101
# 2        101-02                Emergency Cash         101
# 3     101-02-01             Help Pay for Food      101-02
# 4     101-02-02       Help Pay for Healthcare      101-02
# ..          ...                           ...         ...
# 285   111-01-07              Workplace Rights      111-01
# 286      111-02                     Mediation         111
# 287      111-03                        Notary         111
# 288      111-04                Representation         111
# 289      111-05  Translation & Interpretation         111
#
#               parent_name
# 0              somevalues
# 1               Emergency
# 2               Emergency
# 3          Emergency Cash
# 4          Emergency Cash
# ..                    ...
# 285  Advocacy & Legal Aid
# 286                 Legal
# ...

# %%
df1.fillna(0)
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency         0                     0
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
data1 = {
    "A": [1,2,None,4,5,None,7,8,9,10],
    "B": [None,11,12,13,None,15,16,None,18,19]

}
df2 = pd.DataFrame(data1) 
df2
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %%
# replacing with the mean
df2["A"].mean()
# Out:
# np.float64(5.75)

# %%
df2["A"].fillna(df2["A"].mean())
# Out:
# 0     1.00
# 1     2.00
# 2     5.75
# 3     4.00
# 4     5.00
# 5     5.75
# 6     7.00
# 7     8.00
# 8     9.00
# 9    10.00
# Name: A, dtype: float64

# %%
df2["A"].median()
# Out:
# np.float64(6.0)

# %%
df2["A"].fillna(df2["A"].median())
# Out:
# 0     1.0
# 1     2.0
# 2     6.0
# 3     4.0
# 4     5.0
# 5     6.0
# 6     7.0
# 7     8.0
# 8     9.0
# 9    10.0
# Name: A, dtype: float64

# %%
df2
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2.fillna("somevalues")
# Out:
#             A           B
# 0         1.0  somevalues
# 1         2.0        11.0
# 2  somevalues        12.0
# 3         4.0        13.0
# 4         5.0  somevalues
# 5  somevalues        15.0
# 6         7.0        16.0
# 7         8.0  somevalues
# 8         9.0        18.0
# 9        10.0        19.0

# %%
df2.fillna(0)
# Out:
#       A     B
# 0   1.0   0.0
# 1   2.0  11.0
# 2   0.0  12.0
# 3   4.0  13.0
# 4   5.0   0.0
# 5   0.0  15.0
# 6   7.0  16.0
# 7   8.0   0.0
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2.fillna(method="ffill") # forward fill >> start seeing from the bottom of the dataframe nd with the next observed data value
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6084\1854785253.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2.fillna(method="ffill") # forward fill
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   2.0  12.0
# 3   4.0  13.0
# 4   5.0  13.0
# 5   5.0  15.0
# 6   7.0  16.0
# 7   8.0  16.0
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2.fillna(method="bfill")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6084\90801012.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2.fillna(method="bfill")
#       A     B
# 0   1.0  11.0
# 1   2.0  11.0
# 2   4.0  12.0
# 3   4.0  13.0
# 4   5.0  15.0
# 5   7.0  15.0
# 6   7.0  16.0
# 7   8.0  18.0
# 8   9.0  18.0
# 9  10.0  19.0

# %%
# checking duplicate rows
df2.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df.mean(numeric_only=True)
# Out:
# index          445.000000
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# index          445.0000
# PassengerId    446.0000
# Survived         0.0000
# Pclass           3.0000
# Age             28.0000
# SibSp            0.0000
# Parch            0.0000
# Fare            14.4542
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# index          257.353842
# PassengerId    257.353842
# Survived         0.486592
# Pclass           0.836071
# Age             14.526497
# SibSp            1.102743
# Parch            0.806057
# Fare            49.693429
# dtype: float64

# %%
df.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#      index                                               Name  PassengerId  \
# 0        0                            Braund, Mr. Owen Harris            1
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2
# 2        2                             Heikkinen, Miss. Laina            3
# 3        3       Futrelle, Mrs. Jacques Heath (Lily May Peel)            4
# 4        4                           Allen, Mr. William Henry            5
# ..     ...                                                ...          ...
# 886    886                              Montvila, Rev. Juozas          887
# 887    887                       Graham, Miss. Margaret Edith          888
# 888    888           Johnston, Miss. Catherine Helen "Carrie"          889
# 889    889                              Behr, Mr. Karl Howell          890
# 890    890                                Dooley, Mr. Patrick          891
#
# ...

# %%
# what is the avg fare paid by the people who servived?
df[df["Survived"]==1]["Fare"].mean()
# Out:
# np.float64(48.39540760233918)

# %%
# avg fare who did not survived
df[df["Survived"]==0]["Fare"].mean()
# Out:
# np.float64(22.117886885245902)

# %%
#  avg age who survived >> change are to age
df[df["Survived"]==1]["Age"].mean()
# Out:
# np.float64(28.343689655172415)

# %%
#  avg age who survived >> change are to age
# what if i ask max ,min,std age/fare in one result
# groupby

# %%
df.groupby("Survived").mean(numeric_only=True) ## importtant
# Out:
#                index  PassengerId    Pclass        Age     SibSp     Parch  \
# Survived
# 0         446.016393   447.016393  2.531876  30.626179  0.553734  0.329690
# 1         443.368421   444.368421  1.950292  28.343690  0.473684  0.464912
#
#                Fare
# Survived
# 0         22.117887
# 1         48.395408

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.groupby("Survived").sum(numeric_only=True) ## importtant
# Out:
#            index  PassengerId  Pclass       Age  SibSp  Parch        Fare
# Survived
# 0         244863       245412    1390  12985.50    304    181  12142.7199
# 1         151632       151974     667   8219.67    162    159  16551.2294

# %%
df.groupby("Survived").describe() ## importtant
# Out:
#           index                                                            \
#           count        mean         std  min     25%    50%    75%    max
# Survived
# 0         549.0  446.016393  260.640469  0.0  210.00  454.0  674.0  890.0
# 1         342.0  443.368421  252.358840  1.0  249.75  438.5  650.5  889.0
#
#          PassengerId              ... Parch        Fare                        \
#                count        mean  ...   75%  max  count       mean        std
# Survived                          ...
# 0              549.0  447.016393  ...   0.0  6.0  549.0  22.117887  31.388207
# 1              342.0  444.368421  ...   1.0  5.0  342.0  48.395408  66.596998
#
#
#           min      25%   50%   75%       max
# Survived
# 0         0.0   7.8542  10.5  26.0  263.0000
# 1         0.0  12.4750  26.0  57.0  512.3292
#
# [2 rows x 56 columns]

# %%
df[["Survived","Fare"]]
# Out:
#      Survived     Fare
# 0           0   7.2500
# 1           1  71.2833
# 2           1   7.9250
# 3           1  53.1000
# 4           0   8.0500
# ..        ...      ...
# 886         0  13.0000
# 887         1  30.0000
# 888         0  23.4500
# 889         1  30.0000
# 890         0   7.7500
#
# [891 rows x 2 columns]

# %%
import numpy as np
df.groupby(["Survived"])["Fare"].agg([min, "max","median","count",np.std,vars])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6084\135518961.py:2: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby(["Survived"])["Fare"].agg([min, "max","median","count",np.std,vars])
# C:\Users\user\AppData\Local\Temp\ipykernel_6084\135518961.py:2: FutureWarning: The provided callable <function std at 0x00000215040A0360> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   df.groupby(["Survived"])["Fare"].agg([min, "max","median","count",np.std,vars])
#           min       max  median  count        std  \
# Survived
# 0         0.0  263.0000    10.5    549  31.388207
# 1         0.0  512.3292    26.0    342  66.596998
#
# ...

# %%
# gow many passenger survived and not survived
df.groupby(["Sex","Pclass"])["Survived"].sum()
# Out:
# Sex     Pclass
# female  1         91
#         2         70
#         3         72
# male    1         45
#         2         17
#         3         47
# Name: Survived, dtype: int64

# %%
df.groupby(["Sex","Pclass"])["Survived"].sum().to_frame()
# Out:
#                Survived
# Sex    Pclass
# female 1             91
#        2             70
#        3             72
# male   1             45
#        2             17
#        3             47

# %%
df.groupby(["Sex","Pclass"])["Survived"].sum().to_frame().reset_index()
# Out:
#       Sex  Pclass  Survived
# 0  female       1        91
# 1  female       2        70
# 2  female       3        72
# 3    male       1        45
# 4    male       2        17
# 5    male       3        47

# %%
df.groupby(["Sex","Pclass"])["Survived"].sum().to_frame()
# Out:
#                Survived
# Sex    Pclass
# female 1             91
#        2             70
#        3             72
# male   1             45
#        2             17
#        3             47

# %%
df.groupby(["Sex","Pclass"])["Survived"].sum().to_frame().unstack()
# Out:
#        Survived
# Pclass        1   2   3
# Sex
# female       91  70  72
# male         45  17  47

# %%
a = df.groupby("Pclass").sum(numeric_only=True)
a
# Out:
#          index  PassengerId  Survived      Age  SibSp  Parch        Fare
# Pclass
# 1        99489        99705       136  7111.42     90     77  18177.4125
# 2        81872        82056        87  5168.83     74     70   3801.8417
# 3       215134       215625       119  8924.92    302    193   6714.6951

# %%
a.T
# Out:
# Pclass                1           2            3
# index        99489.0000  81872.0000  215134.0000
# PassengerId  99705.0000  82056.0000  215625.0000
# Survived       136.0000     87.0000     119.0000
# Age           7111.4200   5168.8300    8924.9200
# SibSp           90.0000     74.0000     302.0000
# Parch           77.0000     70.0000     193.0000
# Fare         18177.4125   3801.8417    6714.6951

# %%
a.transpose()
# Out:
# Pclass                1           2            3
# index        99489.0000  81872.0000  215134.0000
# PassengerId  99705.0000  82056.0000  215625.0000
# Survived       136.0000     87.0000     119.0000
# Age           7111.4200   5168.8300    8924.9200
# SibSp           90.0000     74.0000     302.0000
# Parch           77.0000     70.0000     193.0000
# Fare         18177.4125   3801.8417    6714.6951

# %%
df.head().T
# Out:
#                                    0  \
# index                              0
# Name         Braund, Mr. Owen Harris
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Sex                             male
# Age                             22.0
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                              1  \
# index                                                        1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# ...

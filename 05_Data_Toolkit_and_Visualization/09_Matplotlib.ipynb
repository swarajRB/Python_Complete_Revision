# %%
# why do we need visualisation ??? Summarisation of data

# matplotlib ,, seaborn ,, plotly ,, bokeh

#matplotlib >>> Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

import warnings

# %%
warnings.filterwarnings('ignore') # suppres the warning

# %%
# bar, line plot , scatter , histogram , pie chart, box plot , violin plot

# %%
# generate random number in numpy 
x = np.random.rand(50)
y = np.random.rand(50)

# %%
x
# Out:
# array([0.94481642, 0.6818878 , 0.92733008, 0.03968397, 0.8569461 ,
#        0.05411702, 0.0289522 , 0.12083972, 0.82318956, 0.70331229,
#        0.65390623, 0.25197558, 0.95363787, 0.05250151, 0.96095202,
#        0.86387447, 0.19255362, 0.53752039, 0.84864156, 0.98689463,
#        0.06363809, 0.97453278, 0.09734692, 0.29218482, 0.07520986,
#        0.61179635, 0.1651685 , 0.3093109 , 0.12432803, 0.62534049,
#        0.29080416, 0.45770878, 0.13230423, 0.14108658, 0.25763479,
#        0.09539663, 0.92863596, 0.16352958, 0.98579028, 0.69106423,
#        0.06468189, 0.90109153, 0.85069462, 0.68473006, 0.81518888,
#        0.90359246, 0.26753107, 0.17960343, 0.24295672, 0.0364721 ])

# %%
df = pd.DataFrame(np.random.randn(1000),columns = ["Data"], index = pd.date_range('2024-07-11', periods= 1000))
df
# Out:
#                 Data
# 2024-07-11 -0.308041
# 2024-07-12 -0.339066
# 2024-07-13  0.439479
# 2024-07-14 -0.056294
# 2024-07-15  1.552624
# ...              ...
# 2027-04-02 -0.464329
# 2027-04-03  0.392277
# 2027-04-04  0.332467
# 2027-04-05  0.608002
# 2027-04-06 -0.716696
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize=(20,8)) # line chart .,, summary >> most of the value are fluctuating from  -3 to 3
# Out:
# <Axes: >

# %%
x
# Out:
# array([0.94481642, 0.6818878 , 0.92733008, 0.03968397, 0.8569461 ,
#        0.05411702, 0.0289522 , 0.12083972, 0.82318956, 0.70331229,
#        0.65390623, 0.25197558, 0.95363787, 0.05250151, 0.96095202,
#        0.86387447, 0.19255362, 0.53752039, 0.84864156, 0.98689463,
#        0.06363809, 0.97453278, 0.09734692, 0.29218482, 0.07520986,
#        0.61179635, 0.1651685 , 0.3093109 , 0.12432803, 0.62534049,
#        0.29080416, 0.45770878, 0.13230423, 0.14108658, 0.25763479,
#        0.09539663, 0.92863596, 0.16352958, 0.98579028, 0.69106423,
#        0.06468189, 0.90109153, 0.85069462, 0.68473006, 0.81518888,
#        0.90359246, 0.26753107, 0.17960343, 0.24295672, 0.0364721 ])

# %%
y = y = np.random.rand(50) 
y
# Out:
# array([0.44640086, 0.54525243, 0.47462046, 0.48850731, 0.49056218,
#        0.20273629, 0.53869785, 0.39113756, 0.62834398, 0.2759094 ,
#        0.7639113 , 0.84319714, 0.76113992, 0.17679787, 0.79841344,
#        0.80213118, 0.2306561 , 0.64964323, 0.67162062, 0.11586163,
#        0.58007769, 0.28716938, 0.0255226 , 0.58127971, 0.97041142,
#        0.51085077, 0.84746652, 0.68148258, 0.8930841 , 0.49389437,
#        0.93817884, 0.66236403, 0.10308521, 0.65731295, 0.30835413,
#        0.12983414, 0.71436997, 0.71894117, 0.88966343, 0.99348269,
#        0.27545964, 0.86576872, 0.7647494 , 0.71407045, 0.22811307,
#        0.81463844, 0.85525974, 0.11226714, 0.56885499, 0.96414824])

# %%
# scatter plot >> A scatter plot is a type of data visualisation that displays values for two variable.

plt.scatter(x,y)

# %%
# line plot
# whenever you want to depict the relation between two variables in the form of Trend 
# mostly on x - asix the date-time column is there 

x = [1, 2 , 3 , 4 , 5] # assume x is no. of day
y = [5, 2 , 7 , 8 , 1] # y is price of stock 

plt.plot (x,y)

# %%
plt.plot (x,y)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot (x,y, color = "red")
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot (x,y, color = "red", marker = "o")
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
x,y
# Out:
# ([1, 2, 3, 4, 5], [5, 2, 7, 8, 1])

# %%
plt.plot (x,y, color = "red", marker = "o", linestyle = "--" )
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot (x,y, color = "red", marker = "o", linestyle = "--", linewidth = 3 )
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot (x,y, color = "red", marker = "o", linestyle = "--", linewidth = 3 ,markersize = 15)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot (x,y, color = "red", marker = "o", linestyle = "--", linewidth = 3 ,markersize = 15)
plt.title("line chart to understand the syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.grid()
plt.show()

# %%
x = [1,2,3,4,5]
y1 = [5,1,7,8,2]
y2 = [7,8,3,5,1]

plt.plot(x, y1, color = "red", marker = "o", linestyle = "--",linewidth = 3 , markersize = 6 , label = "line y1" )

# %%
x = [1,2,3,4,5]
y1 = [5,1,7,8,2]
y2 = [7,8,3,5,1]

plt.plot(x, y1, color = "red", marker = "o", linestyle = "--",linewidth = 3 , markersize = 6 , label = "line y1 as TATA Moters" )
plt.plot(x, y2, color = "blue", marker = "o", linestyle = "--",linewidth = 3 , markersize = 6 , label = "line y2 as TATA powers" )

plt.title("miltiple lines in one plot")
plt.xlabel("Days")
plt.ylabel("Stock price")
plt.legend()

plt.show()

# %%
x = np.linspace(0, 10 , 100)

# %%
plt.plot(x , np.sin(x))
plt.plot(x , np.cos(x))

# %%
plt.plot(x , np.sin(x) , linestyle = "--")

# %%
plt.plot(x , np.sin(x) , linestyle = "-")

# %%
plt.plot(x , np.sin(x) , ".-")

# %%
plt.plot(x , np.sin(x) , linestyle = ":")

# %%
plt.figure() # initialising a page to make a plot
plt.subplot(1,2,1)
plt.plot(x, np.sin(x))

plt.subplot(1,2,2)
plt.plot(x, np.cos(x))

plt.show()

# %%
plt.figure() # initialising a page to make a plot
plt.subplot(2,1,1)
plt.plot(x, np.sin(x))

plt.subplot(2,1,2)
plt.plot(x, np.cos(x))

plt.show()

# %%
plt.figure() # initialising a page to make a plot
plt.subplot(2,1,1)
plt.plot(x, np.sin(x))

plt.subplot(2,1,2)
plt.plot(x, np.cos(x))

plt.show()

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x, np.sin(x))

plt.subplot(2,2,2)
plt.plot(x, np.cos(x))

plt.subplot(2,2,3)
plt.plot(x, np.tan(x))

plt.subplot(2,2,4)
plt.plot(x, np.sin(x+1))

plt.show()

# %%
plt.plot(x, np.sin(x), color="b")

# %%
plt.plot(x, np.sin(x-0), color="b")
plt.ylim(-1.5,1.5)
plt.xlim(1,15)

plt.show()

# %%
plt.plot(x, np.sin(x-0), color="b")
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.axis('equal')
plt.show()

# %%
plt.plot(x, np.sin(x-0), color="b")
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.axis('equal')
plt.grid()
plt.show()

# %%
plt.plot(x, np.sin(x-0), color="b")
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.title("basic syntax")
plt.xlabel("x lable")
plt.ylabel( "y lable")
plt.axis('equal')
plt.grid()
plt.show()

# %%
# Histogram >> continuous numerical data 

# continous >> take any value on a number line
# by delault 10 inteval (bin)

# discreat  >>>  frequence plot

data = np.random.randn(1000) # by default 10 bin are created but mine showing 8 bin
plt.hist(data)
plt.show()

# %%
data = np.random.randn(1000) # by default 10 bin are created but mine showing 8 bin
plt.hist(data , color = "r" , bins = 20)
plt.show()

# %%
# stacked histogram >> two histogram  together

data1 = np.random.normal(0,1,5000)
data2 = np.random.normal(3,2,5000)

# %%
data1
# Out:
# array([-0.26524345,  1.00678275,  0.33366409, ..., -1.24692185,
#         0.42036234,  1.16742494])

# %%
data2
# Out:
# array([ 2.77548732,  3.29968336,  6.08242579, ..., -0.88507841,
#         3.21276852,  4.298248  ])

# %%
plt.hist([data1,data2],bins=20, color=["red","b"],label = ["dist1","dist2"])
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Stacked histogram")
plt.show()

# %%
# scatter plot >> to understand the relationship between two features
x = np.random.rand(50)
y = np.random.rand(50)
x,y
# Out:
# (array([0.7320503 , 0.52218909, 0.95305152, 0.64678213, 0.33660126,
#         0.94522186, 0.67756697, 0.0972179 , 0.37182108, 0.50224023,
#         0.7172736 , 0.84529019, 0.84495157, 0.29870137, 0.31046576,
#         0.73737512, 0.81204835, 0.83952021, 0.75767359, 0.50495522,
#         0.93906673, 0.67411026, 0.09628997, 0.62627786, 0.39802134,
#         0.22576716, 0.17260133, 0.64337293, 0.02086913, 0.25539804,
#         0.44320743, 0.09878163, 0.24964014, 0.70799424, 0.20588274,
#         0.19272473, 0.56344226, 0.40643242, 0.71838876, 0.91477265,
#         0.79941387, 0.4282605 , 0.61707287, 0.19043468, 0.73303029,
#         0.64273313, 0.21271741, 0.58553628, 0.6464498 , 0.81451557]),
#  array([0.71469665, 0.92270205, 0.43219742, 0.68119445, 0.36790696,
#         0.19761493, 0.89476543, 0.18918046, 0.00394067, 0.04941659,
#         0.62628826, 0.63014851, 0.0599573 , 0.28513561, 0.69871015,
#         0.73257714, 0.36031734, 0.40956983, 0.23123587, 0.51464828,
# ...

# %%
plt.scatter(x,y,c="red",marker="o")

# %%
plt.scatter(x,y,c="red",marker="X")

# %%
# bar plot >> t see distribution of caegerical variables
x = ["a","b","c","d"] # name of the student
y = [4,6,1,10] # days present in the class 

plt.bar(x,y , color="r")
# Out:
# <BarContainer object of 4 artists>

# %%
x = ["a","b","c","d"] # name of the student
y = [4,6,1,10] # days present in the class 

plt.barh(x,y , color="r") # horizontal  plot
# Out:
# <BarContainer object of 4 artists>

# %%
# pie chart >> used to understaand the persentage of the data 
langs = ["C", "Python","Java"]
std = [20,100,40]

plt.pie(std,labels = langs , autopct= "%1.1f%%")
plt.title("Pie chart")
plt.show()

# %%
# focus on one segment 
explode = (0.0,0.1,0.1)
langs = ["C", "Python","Java"]
std = [20,100,40]

plt.pie(std,labels = langs , autopct= "%1.1f%%", explode = explode)
plt.title("Pie chart")
plt.show()

# %%
# focus on one segment 
explode = (0.0,0.1,0.1)
langs = ["C", "Python","Java"]
std = [20,100,40]

plt.pie(std,labels = langs , autopct= "%1.1f%%", explode = explode, shadow=True)
plt.title("Pie chart")
plt.show()

# %%
# 3d plots >> 3 dimension plot

x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)

fig = plt.figure()
ax = fig.add_subplot(projection = "3d")
ax.scatter(x,y,z, color ="r")

# %%
data = pd.read_csv("Bank_churn.csv")
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
plt.scatter(x = data["Age"], y = data["Balance"])

# %%
data.plot.scatter(x = "Age", y = "Balance")
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %%
plt.hist(data["Age"], color = "r")
# Out:
# (array([ 611., 2179., 3629., 1871.,  828.,  523.,  208.,  127.,   20.,
#            4.]),
#  array([18. , 25.4, 32.8, 40.2, 47.6, 55. , 62.4, 69.8, 77.2, 84.6, 92. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data["Balance"], color = "r")
# Out:
# (array([3.623e+03, 6.900e+01, 3.600e+02, 1.173e+03, 2.081e+03, 1.747e+03,
#         7.290e+02, 1.860e+02, 3.000e+01, 2.000e+00]),
#  array([     0.   ,  25089.809,  50179.618,  75269.427, 100359.236,
#         125449.045, 150538.854, 175628.663, 200718.472, 225808.281,
#         250898.09 ]),
#  <BarContainer object of 10 artists>)

# %%
# box plot >>  to check the distribution of data and outliers (extreme/ abnornal values)
data.boxplot(column = "Balance")
# Out:
# <Axes: >

# %%
# violoin plot >>>
plt.violinplot(data["Balance"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x2287ae74cb0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x2287d90f4a0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x2287acd6c90>,
#  'cbars': <matplotlib.collections.LineCollection at 0x2287aec6780>}

# %%
# area plot  >> variables changed over time

years = [2021,2018,2022,2023,2017]
category1 = [20,25,30,28,35]
category2 = [10,15,20,18,25]
category3 = [5,8,10,9,15]
plt.stackplot(years,category1,category2,category3,labels=["category1","category2","category3"],
              colors=["skyblue","lightgreen","orange"])
plt.xlabel("Years")
plt.ylabel("Values")
plt.title("Area plot")
plt.legend()
plt.show()
